# %%
#import subprocess
#data = subprocess.check_output(['netsh', 'wlan', 'show', 'profile']).decode('utf-8').split('\n')

#profiles = [i.split(":")[1][1:-1] for i in data if "All User Profile" in i]

#for i in profiles:
    #results = subprocess.check_output(['netsh', 'wlan', 'show', 'profile', i, 'key=clear']).decode('utf-8').split('\n')
    
    #results = [b.split(":")[1][1:-1] for b in results if "key Content" in b]
    
    #try:
     #   print("{:<30}|  {:<}".format(i, results[0]))
    #except IndexError:
     #   print("{:<30}|  {:<}".format(i, " "))
# Out:
# WeAlfalah                     |
# Sab fox hai                   |
# AP                            |
# Newclickzone                  |
# iBall-Baton 2                 |
# iBall-Baton                   |
# We Academy                    |
# Gayas                         |
# LUXVENUS                      |
# AMS                           |
# mohsinpathan                  |
# CoWork                        |
# GREYATOM101                   |
# GREYATOM303 2                 |
# GREYATOM302                   |
# shoeb                         |
# GreyAtom303                   |
# OYOFLAGSHIP                   |
# 2019                          |
# AndroidAP70D2                 |
# safia                         |
# GREYATOM303                   |
# dlink                         |
# realme C2                     |

# %%
                '''CODE TO SHOW WIFI PASSWORD SUCCESSFULLY CONNECTED TO SYSTEM TILL NOW'''
    
import subprocess
data = subprocess.check_output(['netsh', 'wlan', 'show', 'profile']).decode('utf-8').split('\n')

profiles = [i.split(":")[1][1:-1] for i in data if "All User Profile" in i]

for i in profiles:
    profile_details = subprocess.check_output(['netsh', 'wlan', 'show', 'profile', i, 'key=clear']
                                             ).decode('utf-8').split('\n')
    
    password_index = profile_details.index('Security settings \r')+7

    try:
        result = profile_details[password_index].split(":")[1][1:-1]
        print("{:<30}|  {:<}".format(i, result))
    except IndexError:
        print("{:<30}|  {:<}".format(i, "    NO SECURITY OR COULDN'T CONNECT SUCCESSFULLY "))
# Out:
# WeAlfalah                     |  qwertyuiop
# Sab fox hai                   |      NO SECURITY OR COULDN'T CONNECT SUCCESSFULLY
# AP                            |  qwertyuiop
# Newclickzone                  |  1234567890
# iBall-Baton 2                 |  12345678
# iBall-Baton                   |      NO SECURITY OR COULDN'T CONNECT SUCCESSFULLY
# We Academy                    |  WeAlFalah
# Gayas                         |  Gayas@786
# LUXVENUS                      |  wakas143
# AMS                           |  hawa@123
# mohsinpathan                  |      NO SECURITY OR COULDN'T CONNECT SUCCESSFULLY
# CoWork                        |  RedBr!ck@123
# GREYATOM101                   |      NO SECURITY OR COULDN'T CONNECT SUCCESSFULLY
# GREYATOM303 2                 |      NO SECURITY OR COULDN'T CONNECT SUCCESSFULLY
# GREYATOM302                   |      NO SECURITY OR COULDN'T CONNECT SUCCESSFULLY
# shoeb                         |  3690abcd
# GreyAtom303                   |      NO SECURITY OR COULDN'T CONNECT SUCCESSFULLY
# OYOFLAGSHIP                   |      NO SECURITY OR COULDN'T CONNECT SUCCESSFULLY
# 2019                          |  ##@@1923
# AndroidAP70D2                 |  qwertyui
# safia                         |  safia0719
# GREYATOM303                   |      NO SECURITY OR COULDN'T CONNECT SUCCESSFULLY
# dlink                         |  78789800
# realme C2                     |  778a2d902afb

# %%
#results = []
#for i in profiles:
#    results.append(subprocess.check_output(['netsh', 'wlan', 'show', 'profile', i, 'key=clear']).decode('utf-8').split('\n'))
#results
# Out:
# [['\r',
#   'Profile WeAlfalah on interface Wi-Fi: \r',
#   '======================================================================= \r',
#   '\r',
#   'Applied: All User Profile    \r',
#   '\r',
#   'Profile information \r',
#   '------------------- \r',
#   '    Version                : 1\r',
#   '    Type                   : Wireless LAN\r',
#   '    Name                   : WeAlfalah\r',
#   '    Control options        : \r',
#   '        Connection mode    : Connect automatically\r',
#   '        Network broadcast  : Connect even if this network is not broadcasting\r',
#   '        AutoSwitch         : Do not switch to other networks\r',
#   '        MAC Randomization  : Disabled\r',
#   '\r',
#   'Connectivity settings \r',
#   '--------------------- \r',
#   '    Number of SSIDs        : 1\r',
#   '    SSID name              : "WeAlfalah"\r',
#   '    Network type           : Infrastructure\r',
#   '    Radio type             : [ Any Radio Type ]\r',
#   '    Vendor extension          : Not present\r',
#   '\r',
#   'Security settings \r',
#   '----------------- \r',
#   '    Authentication         : WPA2-Personal\r',
#   '    Cipher                 : CCMP\r',
#   '    Authentication         : WPA2-Personal\r',
#   '    Cipher                 : GCMP\r',
#   '    Security key           : Present\r',
#   '    Key Content            : qwertyuiop\r',
#   '\r',
#   'Cost settings \r',
#   '------------- \r',
#   '    Cost                   : Unrestricted\r',
#   '    Congested              : No\r',
#   '    Approaching Data Limit : No\r',
#   '    Over Data Limit        : No\r',
#   '    Roaming                : No\r',
#   '    Cost Source            : Default\r',
#   '\r',
#   ''],
#  ['\r',
#   'Profile Sab fox hai on interface Wi-Fi: \r',
#   '======================================================================= \r',
#   '\r',
#   'Applied: All User Profile    \r',
#   '\r',
#   'Profile information \r',
#   '------------------- \r',
#   '    Version                : 1\r',
#   '    Type                   : Wireless LAN\r',
#   '    Name                   : Sab fox hai\r',
#   '    Control options        : \r',
#   '        Connection mode    : Connect manually\r',
#   '        Network broadcast  : Connect only if this network is broadcasting\r',
#   '        AutoSwitch         : Do not switch to other networks\r',
#   '        MAC Randomization  : Disabled\r',
#   '\r',
#   'Connectivity settings \r',
#   '--------------------- \r',
#   '    Number of SSIDs        : 1\r',
#   '    SSID name              : "Sab fox hai"\r',
#   '    Network type           : Infrastructure\r',
#   '    Radio type             : [ Any Radio Type ]\r',
#   '    Vendor extension          : Not present\r',
#   '\r',
#   'Security settings \r',
#   '----------------- \r',
#   '    Authentication         : WPA-Personal\r',
#   '    Cipher                 : CCMP\r',
#   '    Security key           : Present\r',
#   '\r',
#   'Cost settings \r',
#   '------------- \r',
#   '    Cost                   : Unrestricted\r',
#   '    Congested              : No\r',
#   '    Approaching Data Limit : No\r',
#   '    Over Data Limit        : No\r',
#   '    Roaming                : No\r',
#   '    Cost Source            : Default\r',
#   '\r',
#   ''],
#  ['\r',
#   'Profile AP on interface Wi-Fi: \r',
#   '======================================================================= \r',
#   '\r',
#   'Applied: All User Profile    \r',
#   '\r',
#   'Profile information \r',
#   '------------------- \r',
#   '    Version                : 1\r',
#   '    Type                   : Wireless LAN\r',
#   '    Name                   : AP\r',
#   '    Control options        : \r',
#   '        Connection mode    : Connect automatically\r',
#   '        Network broadcast  : Connect only if this network is broadcasting\r',
#   '        AutoSwitch         : Do not switch to other networks\r',
#   '        MAC Randomization  : Disabled\r',
#   '\r',
#   'Connectivity settings \r',
#   '--------------------- \r',
#   '    Number of SSIDs        : 1\r',
#   '    SSID name              : "AP"\r',
#   '    Network type           : Infrastructure\r',
#   '    Radio type             : [ Any Radio Type ]\r',
#   '    Vendor extension          : Not present\r',
#   '\r',
#   'Security settings \r',
#   '----------------- \r',
#   '    Authentication         : WPA2-Personal\r',
#   '    Cipher                 : CCMP\r',
#   '    Authentication         : WPA2-Personal\r',
#   '    Cipher                 : GCMP\r',
#   '    Security key           : Present\r',
#   '    Key Content            : qwertyuiop\r',
#   '\r',
#   'Cost settings \r',
#   '------------- \r',
#   '    Cost                   : Unrestricted\r',
#   '    Congested              : No\r',
#   '    Approaching Data Limit : No\r',
#   '    Over Data Limit        : No\r',
#   '    Roaming                : No\r',
#   '    Cost Source            : Default\r',
#   '\r',
#   ''],
#  ['\r',
#   'Profile Newclickzone on interface Wi-Fi: \r',
#   '======================================================================= \r',
#   '\r',
#   'Applied: All User Profile    \r',
#   '\r',
#   'Profile information \r',
#   '------------------- \r',
#   '    Version                : 1\r',
#   '    Type                   : Wireless LAN\r',
#   '    Name                   : Newclickzone\r',
#   '    Control options        : \r',
#   '        Connection mode    : Connect automatically\r',
#   '        Network broadcast  : Connect even if this network is not broadcasting\r',
#   '        AutoSwitch         : Do not switch to other networks\r',
#   '        MAC Randomization  : Disabled\r',
#   '\r',
#   'Connectivity settings \r',
#   '--------------------- \r',
#   '    Number of SSIDs        : 1\r',
#   '    SSID name              : "Newclickzone"\r',
#   '    Network type           : Infrastructure\r',
#   '    Radio type             : [ Any Radio Type ]\r',
#   '    Vendor extension          : Not present\r',
#   '\r',
#   'Security settings \r',
#   '----------------- \r',
#   '    Authentication         : WPA2-Personal\r',
#   '    Cipher                 : CCMP\r',
#   '    Authentication         : WPA2-Personal\r',
#   '    Cipher                 : GCMP\r',
#   '    Security key           : Present\r',
#   '    Key Content            : 1234567890\r',
#   '\r',
#   'Cost settings \r',
#   '------------- \r',
#   '    Cost                   : Unrestricted\r',
#   '    Congested              : No\r',
#   '    Approaching Data Limit : No\r',
#   '    Over Data Limit        : No\r',
#   '    Roaming                : No\r',
#   '    Cost Source            : Default\r',
#   '\r',
#   ''],
#  ['\r',
#   'Profile iBall-Baton 2 on interface Wi-Fi: \r',
#   '======================================================================= \r',
#   '\r',
#   'Applied: All User Profile    \r',
#   '\r',
#   'Profile information \r',
#   '------------------- \r',
#   '    Version                : 1\r',
#   '    Type                   : Wireless LAN\r',
#   '    Name                   : iBall-Baton 2\r',
#   '    Control options        : \r',
#   '        Connection mode    : Connect automatically\r',
#   '        Network broadcast  : Connect only if this network is broadcasting\r',
#   '        AutoSwitch         : Do not switch to other networks\r',
#   '        MAC Randomization  : Disabled\r',
#   '\r',
#   'Connectivity settings \r',
#   '--------------------- \r',
#   '    Number of SSIDs        : 1\r',
#   '    SSID name              : "iBall-Baton"\r',
#   '    Network type           : Infrastructure\r',
#   '    Radio type             : [ Any Radio Type ]\r',
#   '    Vendor extension          : Not present\r',
#   '\r',
#   'Security settings \r',
#   '----------------- \r',
#   '    Authentication         : WPA2-Personal\r',
#   '    Cipher                 : CCMP\r',
#   '    Authentication         : WPA2-Personal\r',
#   '    Cipher                 : GCMP\r',
#   '    Security key           : Present\r',
#   '    Key Content            : 12345678\r',
#   '\r',
#   'Cost settings \r',
#   '------------- \r',
#   '    Cost                   : Unrestricted\r',
#   '    Congested              : No\r',
#   '    Approaching Data Limit : No\r',
#   '    Over Data Limit        : No\r',
#   '    Roaming                : No\r',
#   '    Cost Source            : Default\r',
#   '\r',
#   ''],
#  ['\r',
#   'Profile iBall-Baton on interface Wi-Fi: \r',
#   '======================================================================= \r',
#   '\r',
#   'Applied: All User Profile    \r',
#   '\r',
#   'Profile information \r',
#   '------------------- \r',
#   '    Version                : 1\r',
#   '    Type                   : Wireless LAN\r',
#   '    Name                   : iBall-Baton\r',
#   '    Control options        : \r',
#   '        Connection mode    : Connect automatically\r',
#   '        Network broadcast  : Connect only if this network is broadcasting\r',
#   '        AutoSwitch         : Do not switch to other networks\r',
#   '        MAC Randomization  : Disabled\r',
#   '\r',
#   'Connectivity settings \r',
#   '--------------------- \r',
#   '    Number of SSIDs        : 1\r',
#   '    SSID name              : "iBall-Baton"\r',
#   '    Network type           : Infrastructure\r',
#   '    Radio type             : [ Any Radio Type ]\r',
#   '    Vendor extension          : Not present\r',
#   '\r',
#   'Security settings \r',
#   '----------------- \r',
#   '    Authentication         : Open\r',
#   '    Cipher                 : None\r',
#   '    Security key           : Absent\r',
#   '    Key Index              : 1\r',
#   '\r',
#   'Cost settings \r',
#   '------------- \r',
#   '    Cost                   : Unrestricted\r',
#   '    Congested              : No\r',
#   '    Approaching Data Limit : No\r',
#   '    Over Data Limit        : No\r',
#   '    Roaming                : No\r',
#   '    Cost Source            : Default\r',
#   '\r',
#   ''],
#  ['\r',
#   'Profile We Academy on interface Wi-Fi: \r',
#   '======================================================================= \r',
#   '\r',
#   'Applied: All User Profile    \r',
#   '\r',
#   'Profile information \r',
#   '------------------- \r',
#   '    Version                : 1\r',
#   '    Type                   : Wireless LAN\r',
#   '    Name                   : We Academy\r',
#   '    Control options        : \r',
#   '        Connection mode    : Connect automatically\r',
#   '        Network broadcast  : Connect only if this network is broadcasting\r',
#   '        AutoSwitch         : Do not switch to other networks\r',
#   '        MAC Randomization  : Disabled\r',
#   '\r',
#   'Connectivity settings \r',
#   '--------------------- \r',
#   '    Number of SSIDs        : 1\r',
#   '    SSID name              : "We Academy"\r',
#   '    Network type           : Infrastructure\r',
#   '    Radio type             : [ Any Radio Type ]\r',
#   '    Vendor extension          : Not present\r',
#   '\r',
#   'Security settings \r',
#   '----------------- \r',
#   '    Authentication         : WPA2-Personal\r',
#   '    Cipher                 : CCMP\r',
#   '    Authentication         : WPA2-Personal\r',
#   '    Cipher                 : GCMP\r',
#   '    Security key           : Present\r',
#   '    Key Content            : WeAlFalah\r',
#   '\r',
#   'Cost settings \r',
#   '------------- \r',
#   '    Cost                   : Unrestricted\r',
#   '    Congested              : No\r',
#   '    Approaching Data Limit : No\r',
#   '    Over Data Limit        : No\r',
#   '    Roaming                : No\r',
#   '    Cost Source            : Default\r',
#   '\r',
#   ''],
#  ['\r',
#   'Profile Gayas on interface Wi-Fi: \r',
#   '======================================================================= \r',
#   '\r',
#   'Applied: All User Profile    \r',
#   '\r',
#   'Profile information \r',
#   '------------------- \r',
#   '    Version                : 1\r',
#   '    Type                   : Wireless LAN\r',
#   '    Name                   : Gayas\r',
#   '    Control options        : \r',
#   '        Connection mode    : Connect automatically\r',
#   '        Network broadcast  : Connect only if this network is broadcasting\r',
#   '        AutoSwitch         : Do not switch to other networks\r',
#   '        MAC Randomization  : Disabled\r',
#   '\r',
#   'Connectivity settings \r',
#   '--------------------- \r',
#   '    Number of SSIDs        : 1\r',
#   '    SSID name              : "Gayas"\r',
#   '    Network type           : Infrastructure\r',
#   '    Radio type             : [ Any Radio Type ]\r',
#   '    Vendor extension          : Not present\r',
#   '\r',
#   'Security settings \r',
#   '----------------- \r',
#   '    Authentication         : WPA2-Personal\r',
#   '    Cipher                 : CCMP\r',
#   '    Authentication         : WPA2-Personal\r',
#   '    Cipher                 : GCMP\r',
#   '    Security key           : Present\r',
#   '    Key Content            : Gayas@786\r',
#   '\r',
#   'Cost settings \r',
#   '------------- \r',
#   '    Cost                   : Unrestricted\r',
#   '    Congested              : No\r',
#   '    Approaching Data Limit : No\r',
#   '    Over Data Limit        : No\r',
#   '    Roaming                : No\r',
#   '    Cost Source            : Default\r',
#   '\r',
#   ''],
#  ['\r',
#   'Profile LUXVENUS on interface Wi-Fi: \r',
#   '======================================================================= \r',
#   '\r',
#   'Applied: All User Profile    \r',
#   '\r',
#   'Profile information \r',
#   '------------------- \r',
#   '    Version                : 1\r',
#   '    Type                   : Wireless LAN\r',
#   '    Name                   : LUXVENUS\r',
#   '    Control options        : \r',
#   '        Connection mode    : Connect automatically\r',
#   '        Network broadcast  : Connect even if this network is not broadcasting\r',
#   '        AutoSwitch         : Do not switch to other networks\r',
#   '        MAC Randomization  : Disabled\r',
#   '\r',
#   'Connectivity settings \r',
#   '--------------------- \r',
#   '    Number of SSIDs        : 1\r',
#   '    SSID name              : "LUXVENUS"\r',
#   '    Network type           : Infrastructure\r',
#   '    Radio type             : [ Any Radio Type ]\r',
#   '    Vendor extension          : Not present\r',
#   '\r',
#   'Security settings \r',
#   '----------------- \r',
#   '    Authentication         : WPA2-Personal\r',
#   '    Cipher                 : CCMP\r',
#   '    Authentication         : WPA2-Personal\r',
#   '    Cipher                 : GCMP\r',
#   '    Security key           : Present\r',
#   '    Key Content            : wakas143\r',
#   '\r',
#   'Cost settings \r',
#   '------------- \r',
#   '    Cost                   : Unrestricted\r',
#   '    Congested              : No\r',
#   '    Approaching Data Limit : No\r',
#   '    Over Data Limit        : No\r',
#   '    Roaming                : No\r',
#   '    Cost Source            : Default\r',
#   '\r',
#   ''],
#  ['\r',
#   'Profile AMS on interface Wi-Fi: \r',
#   '======================================================================= \r',
#   '\r',
#   'Applied: All User Profile    \r',
#   '\r',
#   'Profile information \r',
#   '------------------- \r',
#   '    Version                : 1\r',
#   '    Type                   : Wireless LAN\r',
#   '    Name                   : AMS\r',
#   '    Control options        : \r',
#   '        Connection mode    : Connect automatically\r',
#   '        Network broadcast  : Connect only if this network is broadcasting\r',
#   '        AutoSwitch         : Do not switch to other networks\r',
#   '        MAC Randomization  : Disabled\r',
#   '\r',
#   'Connectivity settings \r',
#   '--------------------- \r',
#   '    Number of SSIDs        : 1\r',
#   '    SSID name              : "AMS"\r',
#   '    Network type           : Infrastructure\r',
#   '    Radio type             : [ Any Radio Type ]\r',
#   '    Vendor extension          : Not present\r',
#   '\r',
#   'Security settings \r',
#   '----------------- \r',
#   '    Authentication         : WPA2-Personal\r',
#   '    Cipher                 : CCMP\r',
#   '    Authentication         : WPA2-Personal\r',
#   '    Cipher                 : GCMP\r',
#   '    Security key           : Present\r',
#   '    Key Content            : hawa@123\r',
#   '\r',
#   'Cost settings \r',
#   '------------- \r',
#   '    Cost                   : Unrestricted\r',
#   '    Congested              : No\r',
#   '    Approaching Data Limit : No\r',
#   '    Over Data Limit        : No\r',
#   '    Roaming                : No\r',
#   '    Cost Source            : Default\r',
#   '\r',
#   ''],
#  ['\r',
#   'Profile mohsinpathan on interface Wi-Fi: \r',
#   '======================================================================= \r',
#   '\r',
#   'Applied: All User Profile    \r',
#   '\r',
#   'Profile information \r',
#   '------------------- \r',
#   '    Version                : 1\r',
#   '    Type                   : Wireless LAN\r',
#   '    Name                   : mohsinpathan\r',
#   '    Control options        : \r',
#   '        Connection mode    : Connect automatically\r',
#   '        Network broadcast  : Connect only if this network is broadcasting\r',
#   '        AutoSwitch         : Do not switch to other networks\r',
#   '        MAC Randomization  : Disabled\r',
#   '\r',
#   'Connectivity settings \r',
#   '--------------------- \r',
#   '    Number of SSIDs        : 1\r',
#   '    SSID name              : "mohsinpathan"\r',
#   '    Network type           : Infrastructure\r',
#   '    Radio type             : [ Any Radio Type ]\r',
#   '    Vendor extension          : Not present\r',
#   '\r',
#   'Security settings \r',
#   '----------------- \r',
#   '    Authentication         : Open\r',
#   '    Cipher                 : None\r',
#   '    Security key           : Absent\r',
#   '    Key Index              : 1\r',
#   '\r',
#   'Cost settings \r',
#   '------------- \r',
#   '    Cost                   : Unrestricted\r',
#   '    Congested              : No\r',
#   '    Approaching Data Limit : No\r',
#   '    Over Data Limit        : No\r',
#   '    Roaming                : No\r',
#   '    Cost Source            : Default\r',
#   '\r',
#   ''],
#  ['\r',
#   'Profile CoWork on interface Wi-Fi: \r',
#   '======================================================================= \r',
#   '\r',
#   'Applied: All User Profile    \r',
#   '\r',
#   'Profile information \r',
#   '------------------- \r',
#   '    Version                : 1\r',
#   '    Type                   : Wireless LAN\r',
#   '    Name                   : CoWork\r',
#   '    Control options        : \r',
#   '        Connection mode    : Connect automatically\r',
#   '        Network broadcast  : Connect only if this network is broadcasting\r',
#   '        AutoSwitch         : Do not switch to other networks\r',
#   '        MAC Randomization  : Disabled\r',
#   '\r',
#   'Connectivity settings \r',
#   '--------------------- \r',
#   '    Number of SSIDs        : 1\r',
#   '    SSID name              : "CoWork"\r',
#   '    Network type           : Infrastructure\r',
#   '    Radio type             : [ Any Radio Type ]\r',
#   '    Vendor extension          : Not present\r',
#   '\r',
#   'Security settings \r',
#   '----------------- \r',
#   '    Authentication         : WPA2-Personal\r',
#   '    Cipher                 : CCMP\r',
#   '    Authentication         : WPA2-Personal\r',
#   '    Cipher                 : GCMP\r',
#   '    Security key           : Present\r',
#   '    Key Content            : RedBr!ck@123\r',
#   '\r',
#   'Cost settings \r',
#   '------------- \r',
#   '    Cost                   : Unrestricted\r',
#   '    Congested              : No\r',
#   '    Approaching Data Limit : No\r',
#   '    Over Data Limit        : No\r',
#   '    Roaming                : No\r',
#   '    Cost Source            : Default\r',
#   '\r',
#   ''],
#  ['\r',
#   'Profile GREYATOM101 on interface Wi-Fi: \r',
#   '======================================================================= \r',
#   '\r',
#   'Applied: All User Profile    \r',
#   '\r',
#   'Profile information \r',
#   '------------------- \r',
#   '    Version                : 1\r',
#   '    Type                   : Wireless LAN\r',
#   '    Name                   : GREYATOM101\r',
#   '    Control options        : \r',
#   '        Connection mode    : Connect manually\r',
#   '        Network broadcast  : Connect only if this network is broadcasting\r',
#   '        AutoSwitch         : Do not switch to other networks\r',
#   '        MAC Randomization  : Disabled\r',
#   '\r',
#   'Connectivity settings \r',
#   '--------------------- \r',
#   '    Number of SSIDs        : 1\r',
#   '    SSID name              : "GREYATOM101"\r',
#   '    Network type           : Infrastructure\r',
#   '    Radio type             : [ Any Radio Type ]\r',
#   '    Vendor extension          : Not present\r',
#   '\r',
#   'Security settings \r',
#   '----------------- \r',
#   '    Authentication         : Open\r',
#   '    Cipher                 : None\r',
#   '    Security key           : Absent\r',
#   '    Key Index              : 1\r',
#   '\r',
#   'Cost settings \r',
#   '------------- \r',
#   '    Cost                   : Unrestricted\r',
#   '    Congested              : No\r',
#   '    Approaching Data Limit : No\r',
#   '    Over Data Limit        : No\r',
#   '    Roaming                : No\r',
#   '    Cost Source            : Default\r',
#   '\r',
#   ''],
#  ['\r',
#   'Profile GREYATOM303 2 on interface Wi-Fi: \r',
#   '======================================================================= \r',
#   '\r',
#   'Applied: All User Profile    \r',
#   '\r',
#   'Profile information \r',
#   '------------------- \r',
#   '    Version                : 1\r',
#   '    Type                   : Wireless LAN\r',
#   '    Name                   : GREYATOM303 2\r',
#   '    Control options        : \r',
#   '        Connection mode    : Connect automatically\r',
#   '        Network broadcast  : Connect only if this network is broadcasting\r',
#   '        AutoSwitch         : Do not switch to other networks\r',
#   '        MAC Randomization  : Disabled\r',
#   '\r',
#   'Connectivity settings \r',
#   '--------------------- \r',
#   '    Number of SSIDs        : 1\r',
#   '    SSID name              : "GREYATOM303"\r',
#   '    Network type           : Infrastructure\r',
#   '    Radio type             : [ Any Radio Type ]\r',
#   '    Vendor extension          : Not present\r',
#   '\r',
#   'Security settings \r',
#   '----------------- \r',
#   '    Authentication         : Open\r',
#   '    Cipher                 : None\r',
#   '    Security key           : Absent\r',
#   '    Key Index              : 1\r',
#   '\r',
#   'Cost settings \r',
#   '------------- \r',
#   '    Cost                   : Unrestricted\r',
#   '    Congested              : No\r',
#   '    Approaching Data Limit : No\r',
#   '    Over Data Limit        : No\r',
#   '    Roaming                : No\r',
#   '    Cost Source            : Default\r',
#   '\r',
#   ''],
#  ['\r',
#   'Profile GREYATOM302 on interface Wi-Fi: \r',
#   '======================================================================= \r',
#   '\r',
#   'Applied: All User Profile    \r',
#   '\r',
#   'Profile information \r',
#   '------------------- \r',
#   '    Version                : 1\r',
#   '    Type                   : Wireless LAN\r',
#   '    Name                   : GREYATOM302\r',
#   '    Control options        : \r',
#   '        Connection mode    : Connect automatically\r',
#   '        Network broadcast  : Connect only if this network is broadcasting\r',
#   '        AutoSwitch         : Do not switch to other networks\r',
#   '        MAC Randomization  : Disabled\r',
#   '\r',
#   'Connectivity settings \r',
#   '--------------------- \r',
#   '    Number of SSIDs        : 1\r',
#   '    SSID name              : "GREYATOM302"\r',
#   '    Network type           : Infrastructure\r',
#   '    Radio type             : [ Any Radio Type ]\r',
#   '    Vendor extension          : Not present\r',
#   '\r',
#   'Security settings \r',
#   '----------------- \r',
#   '    Authentication         : Open\r',
#   '    Cipher                 : None\r',
#   '    Security key           : Absent\r',
#   '    Key Index              : 1\r',
#   '\r',
#   'Cost settings \r',
#   '------------- \r',
#   '    Cost                   : Unrestricted\r',
#   '    Congested              : No\r',
#   '    Approaching Data Limit : No\r',
#   '    Over Data Limit        : No\r',
#   '    Roaming                : No\r',
#   '    Cost Source            : Default\r',
#   '\r',
#   ''],
#  ['\r',
#   'Profile shoeb on interface Wi-Fi: \r',
#   '======================================================================= \r',
#   '\r',
#   'Applied: All User Profile    \r',
#   '\r',
#   'Profile information \r',
#   '------------------- \r',
#   '    Version                : 1\r',
#   '    Type                   : Wireless LAN\r',
#   '    Name                   : shoeb\r',
#   '    Control options        : \r',
#   '        Connection mode    : Connect automatically\r',
#   '        Network broadcast  : Connect only if this network is broadcasting\r',
#   '        AutoSwitch         : Do not switch to other networks\r',
#   '        MAC Randomization  : Disabled\r',
#   '\r',
#   'Connectivity settings \r',
#   '--------------------- \r',
#   '    Number of SSIDs        : 1\r',
#   '    SSID name              : "shoeb"\r',
#   '    Network type           : Infrastructure\r',
#   '    Radio type             : [ Any Radio Type ]\r',
#   '    Vendor extension          : Not present\r',
#   '\r',
#   'Security settings \r',
#   '----------------- \r',
#   '    Authentication         : WPA2-Personal\r',
#   '    Cipher                 : CCMP\r',
#   '    Authentication         : WPA2-Personal\r',
#   '    Cipher                 : GCMP\r',
#   '    Security key           : Present\r',
#   '    Key Content            : 3690abcd\r',
#   '\r',
#   'Cost settings \r',
#   '------------- \r',
#   '    Cost                   : Unrestricted\r',
#   '    Congested              : No\r',
#   '    Approaching Data Limit : No\r',
#   '    Over Data Limit        : No\r',
#   '    Roaming                : No\r',
#   '    Cost Source            : Default\r',
#   '\r',
#   ''],
#  ['\r',
#   'Profile GreyAtom303 on interface Wi-Fi: \r',
#   '======================================================================= \r',
#   '\r',
#   'Applied: All User Profile    \r',
#   '\r',
#   'Profile information \r',
#   '------------------- \r',
#   '    Version                : 1\r',
#   '    Type                   : Wireless LAN\r',
#   '    Name                   : GreyAtom303\r',
#   '    Control options        : \r',
#   '        Connection mode    : Connect automatically\r',
#   '        Network broadcast  : Connect only if this network is broadcasting\r',
#   '        AutoSwitch         : Do not switch to other networks\r',
#   '        MAC Randomization  : Disabled\r',
#   '\r',
#   'Connectivity settings \r',
#   '--------------------- \r',
#   '    Number of SSIDs        : 1\r',
#   '    SSID name              : "GreyAtom303"\r',
#   '    Network type           : Infrastructure\r',
#   '    Radio type             : [ Any Radio Type ]\r',
#   '    Vendor extension          : Not present\r',
#   '\r',
#   'Security settings \r',
#   '----------------- \r',
#   '    Authentication         : Open\r',
#   '    Cipher                 : None\r',
#   '    Security key           : Absent\r',
#   '    Key Index              : 1\r',
#   '\r',
#   'Cost settings \r',
#   '------------- \r',
#   '    Cost                   : Unrestricted\r',
#   '    Congested              : No\r',
#   '    Approaching Data Limit : No\r',
#   '    Over Data Limit        : No\r',
#   '    Roaming                : No\r',
#   '    Cost Source            : Default\r',
#   '\r',
#   '\r',
#   'Profile GREYATOM303 on interface Wi-Fi: \r',
#   '======================================================================= \r',
#   '\r',
#   'Applied: All User Profile    \r',
#   '\r',
#   'Profile information \r',
#   '------------------- \r',
#   '    Version                : 1\r',
#   '    Type                   : Wireless LAN\r',
#   '    Name                   : GREYATOM303\r',
#   '    Control options        : \r',
#   '        Connection mode    : Connect manually\r',
#   '        Network broadcast  : Connect only if this network is broadcasting\r',
#   '        AutoSwitch         : Do not switch to other networks\r',
#   '        MAC Randomization  : Disabled\r',
#   '\r',
#   'Connectivity settings \r',
#   '--------------------- \r',
#   '    Number of SSIDs        : 1\r',
#   '    SSID name              : "GREYATOM303"\r',
#   '    Network type           : Infrastructure\r',
#   '    Radio type             : [ Any Radio Type ]\r',
#   '    Vendor extension          : Not present\r',
#   '\r',
#   'Security settings \r',
#   '----------------- \r',
#   '    Authentication         : WPA2-Personal\r',
#   '    Cipher                 : CCMP\r',
#   '    Authentication         : WPA2-Personal\r',
#   '    Cipher                 : GCMP\r',
#   '    Security key           : Present\r',
#   '\r',
#   'Cost settings \r',
#   '------------- \r',
#   '    Cost                   : Unrestricted\r',
#   '    Congested              : No\r',
#   '    Approaching Data Limit : No\r',
#   '    Over Data Limit        : No\r',
#   '    Roaming                : No\r',
#   '    Cost Source            : Default\r',
#   '\r',
#   ''],
#  ['\r',
#   'Profile OYOFLAGSHIP on interface Wi-Fi: \r',
#   '======================================================================= \r',
#   '\r',
#   'Applied: All User Profile    \r',
#   '\r',
#   'Profile information \r',
#   '------------------- \r',
#   '    Version                : 1\r',
#   '    Type                   : Wireless LAN\r',
#   '    Name                   : OYOFLAGSHIP\r',
#   '    Control options        : \r',
#   '        Connection mode    : Connect manually\r',
#   '        Network broadcast  : Connect only if this network is broadcasting\r',
#   '        AutoSwitch         : Do not switch to other networks\r',
#   '        MAC Randomization  : Disabled\r',
#   '\r',
#   'Connectivity settings \r',
#   '--------------------- \r',
#   '    Number of SSIDs        : 1\r',
#   '    SSID name              : "OYOFLAGSHIP"\r',
#   '    Network type           : Infrastructure\r',
#   '    Radio type             : [ Any Radio Type ]\r',
#   '    Vendor extension          : Not present\r',
#   '\r',
#   'Security settings \r',
#   '----------------- \r',
#   '    Authentication         : Open\r',
#   '    Cipher                 : None\r',
#   '    Security key           : Absent\r',
#   '    Key Index              : 1\r',
#   '\r',
#   'Cost settings \r',
#   '------------- \r',
#   '    Cost                   : Unrestricted\r',
#   '    Congested              : No\r',
#   '    Approaching Data Limit : No\r',
#   '    Over Data Limit        : No\r',
#   '    Roaming                : No\r',
#   '    Cost Source            : Default\r',
#   '\r',
#   ''],
#  ['\r',
#   'Profile 2019 on interface Wi-Fi: \r',
#   '======================================================================= \r',
#   '\r',
#   'Applied: All User Profile    \r',
#   '\r',
#   'Profile information \r',
#   '------------------- \r',
#   '    Version                : 1\r',
#   '    Type                   : Wireless LAN\r',
#   '    Name                   : 2019\r',
#   '    Control options        : \r',
#   '        Connection mode    : Connect automatically\r',
#   '        Network broadcast  : Connect even if this network is not broadcasting\r',
#   '        AutoSwitch         : Do not switch to other networks\r',
#   '        MAC Randomization  : Disabled\r',
#   '\r',
#   'Connectivity settings \r',
#   '--------------------- \r',
#   '    Number of SSIDs        : 1\r',
#   '    SSID name              : "2019"\r',
#   '    Network type           : Infrastructure\r',
#   '    Radio type             : [ Any Radio Type ]\r',
#   '    Vendor extension          : Not present\r',
#   '\r',
#   'Security settings \r',
#   '----------------- \r',
#   '    Authentication         : WPA2-Personal\r',
#   '    Cipher                 : CCMP\r',
#   '    Authentication         : WPA2-Personal\r',
#   '    Cipher                 : GCMP\r',
#   '    Security key           : Present\r',
#   '    Key Content            : ##@@1923\r',
#   '\r',
#   'Cost settings \r',
#   '------------- \r',
#   '    Cost                   : Unrestricted\r',
#   '    Congested              : No\r',
#   '    Approaching Data Limit : No\r',
#   '    Over Data Limit        : No\r',
#   '    Roaming                : No\r',
#   '    Cost Source            : Default\r',
#   '\r',
#   ''],
#  ['\r',
#   'Profile AndroidAP70D2 on interface Wi-Fi: \r',
#   '======================================================================= \r',
#   '\r',
#   'Applied: All User Profile    \r',
#   '\r',
#   'Profile information \r',
#   '------------------- \r',
#   '    Version                : 1\r',
#   '    Type                   : Wireless LAN\r',
#   '    Name                   : AndroidAP70D2\r',
#   '    Control options        : \r',
#   '        Connection mode    : Connect automatically\r',
#   '        Network broadcast  : Connect only if this network is broadcasting\r',
#   '        AutoSwitch         : Do not switch to other networks\r',
#   '        MAC Randomization  : Disabled\r',
#   '\r',
#   'Connectivity settings \r',
#   '--------------------- \r',
#   '    Number of SSIDs        : 1\r',
#   '    SSID name              : "AndroidAP70D2"\r',
#   '    Network type           : Infrastructure\r',
#   '    Radio type             : [ Any Radio Type ]\r',
#   '    Vendor extension          : Not present\r',
#   '\r',
#   'Security settings \r',
#   '----------------- \r',
#   '    Authentication         : WPA2-Personal\r',
#   '    Cipher                 : CCMP\r',
#   '    Authentication         : WPA2-Personal\r',
#   '    Cipher                 : GCMP\r',
#   '    Security key           : Present\r',
#   '    Key Content            : qwertyui\r',
#   '\r',
#   'Cost settings \r',
#   '------------- \r',
#   '    Cost                   : Fixed\r',
#   '    Congested              : No\r',
#   '    Approaching Data Limit : No\r',
#   '    Over Data Limit        : No\r',
#   '    Roaming                : No\r',
#   '    Cost Source            : Operator\r',
#   '\r',
#   ''],
#  ['\r',
#   'Profile safia on interface Wi-Fi: \r',
#   '======================================================================= \r',
#   '\r',
#   'Applied: All User Profile    \r',
#   '\r',
#   'Profile information \r',
#   '------------------- \r',
#   '    Version                : 1\r',
#   '    Type                   : Wireless LAN\r',
#   '    Name                   : safia\r',
#   '    Control options        : \r',
#   '        Connection mode    : Connect manually\r',
#   '        Network broadcast  : Connect only if this network is broadcasting\r',
#   '        AutoSwitch         : Do not switch to other networks\r',
#   '        MAC Randomization  : Disabled\r',
#   '\r',
#   'Connectivity settings \r',
#   '--------------------- \r',
#   '    Number of SSIDs        : 1\r',
#   '    SSID name              : "safia"\r',
#   '    Network type           : Infrastructure\r',
#   '    Radio type             : [ Any Radio Type ]\r',
#   '    Vendor extension          : Not present\r',
#   '\r',
#   'Security settings \r',
#   '----------------- \r',
#   '    Authentication         : WPA2-Personal\r',
#   '    Cipher                 : CCMP\r',
#   '    Authentication         : WPA2-Personal\r',
#   '    Cipher                 : GCMP\r',
#   '    Security key           : Present\r',
#   '    Key Content            : safia0719\r',
#   '\r',
#   'Cost settings \r',
#   '------------- \r',
#   '    Cost                   : Unrestricted\r',
#   '    Congested              : No\r',
#   '    Approaching Data Limit : No\r',
#   '    Over Data Limit        : No\r',
#   '    Roaming                : No\r',
#   '    Cost Source            : Default\r',
#   '\r',
#   ''],
#  ['\r',
#   'Profile GreyAtom303 on interface Wi-Fi: \r',
#   '======================================================================= \r',
#   '\r',
#   'Applied: All User Profile    \r',
#   '\r',
#   'Profile information \r',
#   '------------------- \r',
#   '    Version                : 1\r',
#   '    Type                   : Wireless LAN\r',
#   '    Name                   : GreyAtom303\r',
#   '    Control options        : \r',
#   '        Connection mode    : Connect automatically\r',
#   '        Network broadcast  : Connect only if this network is broadcasting\r',
#   '        AutoSwitch         : Do not switch to other networks\r',
#   '        MAC Randomization  : Disabled\r',
#   '\r',
#   'Connectivity settings \r',
#   '--------------------- \r',
#   '    Number of SSIDs        : 1\r',
#   '    SSID name              : "GreyAtom303"\r',
#   '    Network type           : Infrastructure\r',
#   '    Radio type             : [ Any Radio Type ]\r',
#   '    Vendor extension          : Not present\r',
#   '\r',
#   'Security settings \r',
#   '----------------- \r',
#   '    Authentication         : Open\r',
#   '    Cipher                 : None\r',
#   '    Security key           : Absent\r',
#   '    Key Index              : 1\r',
#   '\r',
#   'Cost settings \r',
#   '------------- \r',
#   '    Cost                   : Unrestricted\r',
#   '    Congested              : No\r',
#   '    Approaching Data Limit : No\r',
#   '    Over Data Limit        : No\r',
#   '    Roaming                : No\r',
#   '    Cost Source            : Default\r',
#   '\r',
#   '\r',
#   'Profile GREYATOM303 on interface Wi-Fi: \r',
#   '======================================================================= \r',
#   '\r',
#   'Applied: All User Profile    \r',
#   '\r',
#   'Profile information \r',
#   '------------------- \r',
#   '    Version                : 1\r',
#   '    Type                   : Wireless LAN\r',
#   '    Name                   : GREYATOM303\r',
#   '    Control options        : \r',
#   '        Connection mode    : Connect manually\r',
#   '        Network broadcast  : Connect only if this network is broadcasting\r',
#   '        AutoSwitch         : Do not switch to other networks\r',
#   '        MAC Randomization  : Disabled\r',
#   '\r',
#   'Connectivity settings \r',
#   '--------------------- \r',
#   '    Number of SSIDs        : 1\r',
#   '    SSID name              : "GREYATOM303"\r',
#   '    Network type           : Infrastructure\r',
#   '    Radio type             : [ Any Radio Type ]\r',
#   '    Vendor extension          : Not present\r',
#   '\r',
#   'Security settings \r',
#   '----------------- \r',
#   '    Authentication         : WPA2-Personal\r',
#   '    Cipher                 : CCMP\r',
#   '    Authentication         : WPA2-Personal\r',
#   '    Cipher                 : GCMP\r',
#   '    Security key           : Present\r',
#   '\r',
#   'Cost settings \r',
#   '------------- \r',
#   '    Cost                   : Unrestricted\r',
#   '    Congested              : No\r',
#   '    Approaching Data Limit : No\r',
#   '    Over Data Limit        : No\r',
#   '    Roaming                : No\r',
#   '    Cost Source            : Default\r',
#   '\r',
#   ''],
#  ['\r',
#   'Profile dlink on interface Wi-Fi: \r',
#   '======================================================================= \r',
#   '\r',
#   'Applied: All User Profile    \r',
#   '\r',
#   'Profile information \r',
#   '------------------- \r',
#   '    Version                : 1\r',
#   '    Type                   : Wireless LAN\r',
#   '    Name                   : dlink\r',
#   '    Control options        : \r',
#   '        Connection mode    : Connect automatically\r',
#   '        Network broadcast  : Connect only if this network is broadcasting\r',
#   '        AutoSwitch         : Do not switch to other networks\r',
#   '        MAC Randomization  : Disabled\r',
#   '\r',
#   'Connectivity settings \r',
#   '--------------------- \r',
#   '    Number of SSIDs        : 1\r',
#   '    SSID name              : "dlink"\r',
#   '    Network type           : Infrastructure\r',
#   '    Radio type             : [ Any Radio Type ]\r',
#   '    Vendor extension          : Not present\r',
#   '\r',
#   'Security settings \r',
#   '----------------- \r',
#   '    Authentication         : WPA2-Personal\r',
#   '    Cipher                 : CCMP\r',
#   '    Authentication         : WPA2-Personal\r',
#   '    Cipher                 : GCMP\r',
#   '    Security key           : Present\r',
#   '    Key Content            : 78789800\r',
#   '\r',
#   'Cost settings \r',
#   '------------- \r',
#   '    Cost                   : Unrestricted\r',
#   '    Congested              : No\r',
#   '    Approaching Data Limit : No\r',
#   '    Over Data Limit        : No\r',
#   '    Roaming                : No\r',
#   '    Cost Source            : Default\r',
#   '\r',
#   ''],
#  ['\r',
#   'Profile realme C2 on interface Wi-Fi: \r',
#   '======================================================================= \r',
#   '\r',
#   'Applied: All User Profile    \r',
#   '\r',
#   'Profile information \r',
#   '------------------- \r',
#   '    Version                : 1\r',
#   '    Type                   : Wireless LAN\r',
#   '    Name                   : realme C2\r',
#   '    Control options        : \r',
#   '        Connection mode    : Connect automatically\r',
#   '        Network broadcast  : Connect only if this network is broadcasting\r',
#   '        AutoSwitch         : Do not switch to other networks\r',
#   '        MAC Randomization  : Disabled\r',
#   '\r',
#   'Connectivity settings \r',
#   '--------------------- \r',
#   '    Number of SSIDs        : 1\r',
#   '    SSID name              : "realme C2"\r',
#   '    Network type           : Infrastructure\r',
#   '    Radio type             : [ Any Radio Type ]\r',
#   '    Vendor extension          : Not present\r',
#   '\r',
#   'Security settings \r',
#   '----------------- \r',
#   '    Authentication         : WPA2-Personal\r',
#   '    Cipher                 : CCMP\r',
#   '    Authentication         : WPA2-Personal\r',
#   '    Cipher                 : GCMP\r',
#   '    Security key           : Present\r',
#   '    Key Content            : 778a2d902afb\r',
#   '\r',
#   'Cost settings \r',
#   '------------- \r',
#   '    Cost                   : Unrestricted\r',
#   '    Congested              : No\r',
#   '    Approaching Data Limit : No\r',
#   '    Over Data Limit        : No\r',
#   '    Roaming                : No\r',
#   '    Cost Source            : Default\r',
#   '\r',
#   '']]
